# %% [markdown]
# ## Importing Dependencies

# %%
import pandas as pd
import numpy as np
import geocoder

# %% [markdown]
# ## Reading Files

# %%
data = pd.read_csv("toronto.csv")
data.head()
# Out:
#    Unnamed: 0 PostalCode           Borough                        Neighborhood
# 0           0        M3A        North York                           Parkwoods
# 1           1        M4A        North York                    Victoria Village
# 2           2        M5A  Downtown Toronto         Regent Park ,  Harbourfront
# 3           3        M6A        North York  Lawrence Manor ,  Lawrence Heights
# 4           4        M7A      Queen's Park       Ontario Provincial Government

# %% [markdown]
# ## Getting latitudes and longitudes of all the postal codes

# %%
def get_lati_long(postal_code):
    lati_long = None
    while(lati_long is None):
        geo = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
        lati_long = geo.latlng
    return lati_long

# %%
pcs = data['PostalCode']    
coordinates = [ get_lati_long(postal_code) for postal_code  in pcs.tolist() ]

# %%
coordinates_df = pd.DataFrame(coordinates, columns=['Latitude', 'Longitude'])
data['Latitude'] = coordinates_df['Latitude']
data['Longitude'] = coordinates_df['Longitude']

# %%
data
# Out:
#      Unnamed: 0 PostalCode           Borough  \
# 0             0        M3A        North York
# 1             1        M4A        North York
# 2             2        M5A  Downtown Toronto
# 3             3        M6A        North York
# 4             4        M7A      Queen's Park
# ..          ...        ...               ...
# 98           98        M8X         Etobicoke
# 99           99        M4Y  Downtown Toronto
# 100         100        M7Y      East Toronto
# 101         101        M8Y         Etobicoke
# 102         102        M8Z         Etobicoke
#
#                                           Neighborhood  Latitude  Longitude
# 0                                            Parkwoods  43.75245  -79.32991
# 1                                     Victoria Village  43.73057  -79.31306
# 2                          Regent Park ,  Harbourfront  43.65512  -79.36264
# 3                   Lawrence Manor ,  Lawrence Heights  43.72327  -79.45042
# ...

# %%
data.to_csv('toronto_part2.csv',index=False)
